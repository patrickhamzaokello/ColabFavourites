# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickhamzaokello/ColabFavourites/blob/main/Create_Intents_from_Website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install spaCy and download the English model:
# pip install spacy
# python -m spacy download en_core_web_sm

# %%
import requests
from bs4 import BeautifulSoup
import markdown
import os
import time
from urllib.parse import urljoin, urlparse
import re
from typing import Set, List, Dict

class BankWebsiteScraper:
    def __init__(self, base_url: str, output_dir: str = "bank_content"):
        self.base_url = base_url
        self.output_dir = output_dir
        self.visited_urls: Set[str] = set()
        self.session = requests.Session()
        # Add common browser headers to avoid being blocked
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        })

        # Create output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)

    def is_valid_url(self, url: str) -> bool:
        """Check if URL belongs to the same domain and is a valid page"""
        parsed_base = urlparse(self.base_url)
        parsed_url = urlparse(url)
        return (parsed_url.netloc == parsed_base.netloc and
                not any(ext in url.lower() for ext in ['.pdf', '.jpg', '.png', '.gif', '.css', '.js']) and
                '#' not in url)

    def clean_text(self, text: str) -> str:
        """Clean and format text content"""
        # Remove extra whitespace and newlines
        text = ' '.join(text.split())
        # Remove special characters
        text = re.sub(r'[^\w\s\-.,?!()]', '', text)
        return text.strip()

    def html_to_markdown(self, soup: BeautifulSoup, url: str) -> str:
        """Convert HTML content to markdown format"""
        markdown_content = []

        # Add page title
        if soup.title:
            markdown_content.append(f"# {soup.title.string.strip()}\n")

        # Add URL reference
        markdown_content.append(f"Source: {url}\n")

        # Process main content
        main_content = soup.find('main') or soup.find('article') or soup.find('div', {'class': ['content', 'main-content']})
        if not main_content:
            main_content = soup

        # Process headings
        for heading in main_content.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6']):
            level = int(heading.name[1])
            markdown_content.append(f"{'#' * level} {self.clean_text(heading.text)}\n")

        # Process paragraphs
        for p in main_content.find_all('p'):
            text = self.clean_text(p.text)
            if text:
                markdown_content.append(f"{text}\n")

        # Process lists
        for ul in main_content.find_all(['ul', 'ol']):
            for li in ul.find_all('li'):
                text = self.clean_text(li.text)
                if text:
                    markdown_content.append(f"- {text}\n")

        return '\n'.join(markdown_content)

    def scrape_page(self, url: str) -> List[str]:
        """Scrape single page and return new URLs to visit"""
        if url in self.visited_urls:
            return []

        self.visited_urls.add(url)
        print(f"Scraping: {url}")

        try:
            response = self.session.get(url, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # Convert content to markdown
            markdown_content = self.html_to_markdown(soup, url)

            # Save to file
            filename = f"{len(self.visited_urls):04d}_{urlparse(url).path.replace('/', '_')}.md"
            if filename == '0000_.md':
                filename = '0000_home.md'

            with open(os.path.join(self.output_dir, filename), 'w', encoding='utf-8') as f:
                f.write(markdown_content)

            # Find new URLs
            new_urls = []
            for link in soup.find_all('a', href=True):
                new_url = urljoin(url, link['href'])
                if self.is_valid_url(new_url) and new_url not in self.visited_urls:
                    new_urls.append(new_url)

            time.sleep(1)  # Be nice to the server
            return new_urls

        except Exception as e:
            print(f"Error scraping {url}: {str(e)}")
            return []

    def scrape_website(self):
        """Scrape entire website"""
        urls_to_visit = [self.base_url]

        while urls_to_visit:
            url = urls_to_visit.pop(0)
            new_urls = self.scrape_page(url)
            urls_to_visit.extend(new_urls)

class IntentTrainer:
    def __init__(self, markdown_dir: str):
        self.markdown_dir = markdown_dir
        self.content_by_category: Dict[str, List[str]] = {}

    def load_markdown_files(self):
        """Load and categorize markdown content"""
        for filename in os.listdir(self.markdown_dir):
            if filename.endswith('.md'):
                with open(os.path.join(self.markdown_dir, filename), 'r', encoding='utf-8') as f:
                    content = f.read()

                    # Extract categories based on headings and content
                    categories = self.identify_categories(content)
                    for category, text in categories.items():
                        if category not in self.content_by_category:
                            self.content_by_category[category] = []
                        self.content_by_category[category].extend(text)

    def identify_categories(self, content: str) -> Dict[str, List[str]]:
        """Identify banking categories from content"""
        categories = {}
        current_category = "general"
        current_text = []

        # Define category keywords
        category_keywords = {
            'account': ['account', 'savings', 'current', 'deposit'],
            'payments': ['bill', 'payment', 'utility', 'electricity', 'water'],
            'transfers': ['transfer', 'send money', 'remittance'],
            'loans': ['loan', 'credit', 'mortgage', 'financing'],
            'cards': ['card', 'credit card', 'debit card', 'atm'],
            'investments': ['investment', 'fixed deposit', 'mutual fund'],
            'digital_banking': ['online', 'mobile', 'internet banking', 'app']
        }

        for line in content.split('\n'):
            # Check if line is a heading
            if line.startswith('#'):
                # Save previous category
                if current_text:
                    if current_category not in categories:
                        categories[current_category] = []
                    categories[current_category].extend(current_text)
                    current_text = []

                # Determine new category based on heading
                heading = line.strip('#').strip().lower()
                current_category = "general"
                for category, keywords in category_keywords.items():
                    if any(keyword in heading for keyword in keywords):
                        current_category = category
                        break
            else:
                current_text.append(line.strip())

        # Save last category
        if current_text:
            if current_category not in categories:
                categories[current_category] = []
            categories[current_category].extend(current_text)

        return categories

    def generate_intents(self) -> Dict[str, List[str]]:
        """Generate intent patterns from categorized content"""
        intent_patterns = {}

        for category, content in self.content_by_category.items():
            patterns = self.extract_patterns(content)
            intent_patterns[category] = patterns

        return intent_patterns

    def extract_patterns(self, content: List[str]) -> List[str]:
        """Extract likely user intent patterns from content"""
        patterns = []

        # Common question patterns
        question_starters = ['how to', 'what is', 'where can', 'when does', 'can i']
        action_verbs = ['get', 'apply', 'open', 'start', 'view', 'check', 'pay', 'transfer']

        for line in content:
            line = line.lower()
            # Extract questions
            for starter in question_starters:
                if starter in line:
                    question = re.search(f"{starter}.*?[.?!]", line)
                    if question:
                        patterns.append(question.group(0))

            # Extract action statements
            for verb in action_verbs:
                if verb in line:
                    action = re.search(f"{verb}.*?[.?!]", line)
                    if action:
                        patterns.append(action.group(0))

        return list(set(patterns))  # Remove duplicates

# %%
def main():
    # Initialize scraper
    scraper = BankWebsiteScraper('https://www.gtbank.co.ug/')

    # Scrape website
    scraper.scrape_website()

if __name__ == "__main__":
    main()
# Out:
# Scraping: https://www.gtbank.co.ug/
# Scraping: https://www.gtbank.co.ug/locate/branches
# Scraping: https://www.gtbank.co.ug/locate/atms
# Scraping: https://www.gtbank.co.ug/media-centre
# Scraping: https://www.gtbank.co.ug/help-centre
# Scraping: https://www.gtbank.co.ug/security-centre
# Scraping: https://www.gtbank.co.ug/personal-banking
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gtsave
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gtsave-plus
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/sks-account
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gt-target
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gt-seniors-account
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gt-salary-account
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/gtcrea8-account
# Scraping: https://www.gtbank.co.ug/personal-banking/ways-to-bank
# Scraping: https://www.gtbank.co.ug/about/atms
# Scraping: https://www.gtbank.co.ug/about/cards
# Scraping: https://www.gtbank.co.ug/personal-banking/loans
# Scraping: https://www.gtbank.co.ug/personal-banking/loans/salary-loans
# Scraping: https://www.gtbank.co.ug/personal-banking/loans/personal-development-loans
# Scraping: https://www.gtbank.co.ug/personal-banking/services
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3-3
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3-3-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3-2-2
# Scraping: https://www.gtbank.co.ug/personal-banking/services/services-2-2/services-2-3-2-2-2
# Scraping: https://www.gtbank.co.ug/business-banking
# Scraping: https://www.gtbank.co.ug/business-banking/accounts
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbusiness-account
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtcurrent-account
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbank-ngo-account
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbusiness-standard-account
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbusiness-standard-account-2
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbusiness-standard-account-2-2
# Scraping: https://www.gtbank.co.ug/business-banking/accounts/gtbusiness-standard-account-2-3
# Scraping: https://www.gtbank.co.ug/business-banking/loans
# Scraping: https://www.gtbank.co.ug/business-banking/loans/term-loans
# Scraping: https://www.gtbank.co.ug/business-banking/loans/bill-discounting
# Scraping: https://www.gtbank.co.ug/business-banking/loans/invoice-discounting
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/letter-of-credit
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/import-letters-of-credit-services
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/export-letters-of-credit-services
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/documentary-collections
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/documentary-import-collections
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/export-documentary-collections
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/clean-collections
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/negotiation-of-export-bills
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/bill-avalisation-service
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/suppliers-credit-financing
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/post-import-financing
# Scraping: https://www.gtbank.co.ug/business-banking/loans/gt-trade-finance/bank-guarantees
# Scraping: https://www.gtbank.co.ug/about
# Scraping: https://www.gtbank.co.ug/about/our-company
# Scraping: https://www.gtbank.co.ug/about/our-company/history
# Scraping: https://www.gtbank.co.ug/about/our-company/people
# Scraping: https://www.gtbank.co.ug/about/careers/our-people
# Scraping: https://www.gtbank.co.ug/about/our-company/recognition-and-awards-2
# Scraping: https://www.gtbank.co.ug/about/our-company/brand
# Scraping: https://www.gtbank.co.ug/about/careers
# Scraping: https://www.gtbank.co.ug/about/careers/why-join-gtbank
# Scraping: https://www.gtbank.co.ug/about/careers/working-at-gtbank
# Scraping: https://www.gtbank.co.ug/about/careers/career-opportunities
# Scraping: https://www.gtbank.co.ug/about/career
# Scraping: https://www.gtbank.co.ug/about/scam-job-offers
# Scraping: https://www.gtbank.co.ug/about/corporate-social-responsibility
# Scraping: https://www.gtbank.co.ug/about/corporate-social-responsibility/our-approach
# Scraping: https://www.gtbank.co.ug/investor-relations
# Scraping: https://www.gtbank.co.ug/about/our-company/financial-information
# Scraping: https://www.gtbank.co.ug/about/our-company/recognition-and-awards
# Scraping: https://www.gtbank.co.ug/help-centre/contact-us
# Scraping: https://www.gtbank.co.ug/help-centre/complaints-enquiries
# Scraping: https://www.gtbank.co.ug/help-centre/newsletter-subscription
# Scraping: https://www.gtbank.co.ug/help-centre/whistle-blower
# Scraping: https://www.gtbank.co.ug/locate
# Scraping: https://www.gtbank.co.ug/help-centre/download-forms
# Scraping: https://www.gtbank.co.ug/about/contact
# Scraping: https://www.gtbank.co.ug/about/-2
# Scraping: https://www.gtbank.co.ug/terms-and-conditions
# Scraping: https://www.gtbank.co.ug/about/digital-services-terms-and-conditions
# Scraping: https://www.gtbank.co.ug/privacy-policy
# Scraping: https://www.gtbank.co.ug/sitemap
# Scraping: https://www.gtbank.co.ug/about/deposits-are-protected-by-deposit-protection-fund-upto-10m
# Scraping: https://www.gtbank.co.ug/branches
# Scraping: https://www.gtbank.co.ug/atms
# Scraping: https://www.gtbank.co.ug/media-centre/gtbank-in-the-news
# Scraping: https://www.gtbank.co.ug/media-centre/press-releases
# Scraping: https://www.gtbank.co.ug/media-centre/videos
# Scraping: https://www.gtbank.co.ug/media-centre/all-content
# Scraping: https://www.gtbank.co.ug/personal-banking/ways-to-bank/gtconnect
# Error scraping https://www.gtbank.co.ug/personal-banking/ways-to-bank/gtconnect: 404 Client Error: Not Found for url: https://www.gtbank.co.ug/personal-banking/ways-to-bank/gtconnect
# Scraping: https://www.gtbank.co.ug/business-banking/loans/overdraft-facilities
# Error scraping https://www.gtbank.co.ug/business-banking/loans/overdraft-facilities: 404 Client Error: Not Found for url: https://www.gtbank.co.ug/business-banking/loans/overdraft-facilities
# Scraping: https://www.gtbank.co.ug/about/our-company/corporate-governance
# Scraping: https://www.gtbank.co.ug/investor-relations/help-contact
# Error scraping https://www.gtbank.co.ug/investor-relations/help-contact: 404 Client Error: Not Found for url: https://www.gtbank.co.ug/investor-relations/help-contact
# Scraping: https://www.gtbank.co.ug/about/corporate-social-responsibility/education
# Scraping: https://www.gtbank.co.ug/about/corporate-social-responsibility/sports
# Scraping: https://www.gtbank.co.ug/about/download-buttons
# Scraping: https://www.gtbank.co.ug/about/open-account
# Scraping: https://www.gtbank.co.ug/about/dpf
# Scraping: https://www.gtbank.co.ug/locate/branches/kira-road-head-office
# Scraping: https://www.gtbank.co.ug/locate/branches/buganda-road
# Scraping: https://www.gtbank.co.ug/locate/branches/colville-street
# Scraping: https://www.gtbank.co.ug/locate/branches/kyaliwajjala-branch
# Scraping: https://www.gtbank.co.ug/locate/branches/industrial-area-branch
# Scraping: https://www.gtbank.co.ug/locate/branches/nakivubo-branch
# Scraping: https://www.gtbank.co.ug/locate/branches/mbarara-branch
# Scraping: https://www.gtbank.co.ug/business-banking/cards
# Scraping: https://www.gtbank.co.ug/business-banking/cards/corporate-purchasing-card
# Scraping: https://www.gtbank.co.ug/business-banking/cards/corporate-executive-t-e-card
# Scraping: https://www.gtbank.co.ug/business-banking/services
# Scraping: https://www.gtbank.co.ug/business-banking/services/bankers-acceptances
# Scraping: https://www.gtbank.co.ug/business-banking/services/cheques-writing
# Scraping: https://www.gtbank.co.ug/business-banking/services/funds-portfolio-management
# Scraping: https://www.gtbank.co.ug/business-banking/services/loan-syndication
# Scraping: https://www.gtbank.co.ug/business-banking/services/money-market-instruments
# Scraping: https://www.gtbank.co.ug/business-banking/services/foreign-currency-transfer
# Scraping: https://www.gtbank.co.ug/business-banking/services/gaps
# Scraping: https://www.gtbank.co.ug/business-banking/services/pos
# Scraping: https://www.gtbank.co.ug/business-banking/services/e-zwich-pos
# Scraping: https://www.gtbank.co.ug/business-banking/services/gt-trade-tracker
# Scraping: https://www.gtbank.co.ug/business-banking/services/gtpay
# Scraping: https://www.gtbank.co.ug/business-banking/services/ugpay
# Scraping: https://www.gtbank.co.ug/business-banking/services/overdraft-facilities
# Scraping: https://www.gtbank.co.ug/business-banking/services/gtbusiness-loans
# Scraping: https://www.gtbank.co.ug/business-banking/services/bills-discounting
# Scraping: https://www.gtbank.co.ug/business-banking/services/invoice-discounting
# Scraping: https://www.gtbank.co.ug/business-banking/services/trade-finance
# Scraping: https://www.gtbank.co.ug/business-banking/services/asset-financing
# Scraping: https://www.gtbank.co.ug/help-centre/financial-calculators
# Scraping: https://www.gtbank.co.ug/personal-banking/accounts/services-2
# Scraping: https://www.gtbank.co.ug/security-centre/security-information
# Scraping: https://www.gtbank.co.ug/career
# Scraping: https://www.gtbank.co.ug/pay-tax
# Scraping: https://www.gtbank.co.ug/media-centre/press-releases/737-services

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline
import torch
from sentence_transformers import SentenceTransformer
import spacy

# %%
class IntentClassifier:
    def __init__(self, intents, default_intent='menu'):
        self.intents = intents
        self.default_intent = default_intent

        # Initialize models
        self.sentence_transformer = SentenceTransformer('all-MiniLM-L6-v2')
        self.nlp = spacy.load('en_core_web_sm')
        self.tfidf = TfidfVectorizer()

        # Prepare intent embeddings
        self.prepare_intent_embeddings()

    def prepare_intent_embeddings(self):
        # Flatten intents for embedding
        self.all_examples = []
        self.intent_map = []
        for intent, examples in self.intents.items():
            self.all_examples.extend(examples)
            self.intent_map.extend([intent] * len(examples))

        # Create embeddings for all examples
        self.example_embeddings = self.sentence_transformer.encode(self.all_examples)

        # Create TF-IDF matrix
        self.tfidf_matrix = self.tfidf.fit_transform(self.all_examples)

    def classify_with_transformer(self, user_message, threshold=0.6):
        # Get message embedding
        message_embedding = self.sentence_transformer.encode([user_message])

        # Calculate similarities
        similarities = cosine_similarity(message_embedding, self.example_embeddings)[0]

        # Get best match
        best_match_idx = np.argmax(similarities)
        best_similarity = similarities[best_match_idx]

        if best_similarity >= threshold:
            return self.intent_map[best_match_idx], best_similarity
        return self.default_intent, best_similarity

    def classify_with_tfidf(self, user_message, threshold=0.3):
        # Transform user message
        message_tfidf = self.tfidf.transform([user_message])

        # Calculate similarities
        similarities = cosine_similarity(message_tfidf, self.tfidf_matrix)[0]

        # Get best match
        best_match_idx = np.argmax(similarities)
        best_similarity = similarities[best_match_idx]

        if best_similarity >= threshold:
            return self.intent_map[best_match_idx], best_similarity
        return self.default_intent, best_similarity

    def classify_with_spacy(self, user_message, threshold=0.7):
        doc = self.nlp(user_message.lower())

        best_similarity = 0
        best_intent = self.default_intent

        for intent, examples in self.intents.items():
            for example in examples:
                example_doc = self.nlp(example.lower())
                similarity = doc.similarity(example_doc)

                if similarity > best_similarity:
                    best_similarity = similarity
                    best_intent = intent

        if best_similarity >= threshold:
            return best_intent, best_similarity
        return self.default_intent, best_similarity

    def ensemble_classify(self, user_message, weights={'transformer': 0.5, 'tfidf': 0.3, 'spacy': 0.2}):
        # Get classifications from all methods
        transformer_intent, transformer_score = self.classify_with_transformer(user_message)
        tfidf_intent, tfidf_score = self.classify_with_tfidf(user_message)
        spacy_intent, spacy_score = self.classify_with_spacy(user_message)

        # Weight the scores
        weighted_scores = {
            transformer_intent: transformer_score * weights['transformer'],
            tfidf_intent: tfidf_score * weights['tfidf'],
            spacy_intent: spacy_score * weights['spacy']
        }

        # Get the intent with highest weighted score
        final_intent = max(weighted_scores.items(), key=lambda x: x[1])[0]

        return final_intent

# %% [markdown]
# # **Intent Generator from Scraped Content**
#
# This script will:
#
# 1. Process your scraped content and extract meaningful sentences
# 2. Categorize content into banking-related categories
# 3. Generate various intent patterns from the content
# 4. Remove duplicates and cluster similar intents
# 5. Organize everything into a structured dictionary

# %%
import os
import re
from typing import Dict, List, Set
from collections import defaultdict
import spacy
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

class IntentGenerator:
    def __init__(self, content_dir: str):
        self.content_dir = content_dir
        # Load spaCy model for NLP tasks
        self.nlp = spacy.load('en_core_web_sm')

        # Common banking terms and their categories
        self.banking_categories = {
            'account': ['account', 'savings', 'current', 'deposit', 'open', 'create', 'balance'],
            'payments': ['pay', 'bill', 'utility', 'electricity', 'water', 'tax', 'fees'],
            'transfers': ['transfer', 'send', 'receive', 'remit', 'swift', 'wire'],
            'loans': ['loan', 'borrow', 'credit', 'mortgage', 'financing'],
            'cards': ['card', 'credit', 'debit', 'atm', 'pin', 'contactless'],
            'investments': ['invest', 'fixed deposit', 'mutual fund', 'stocks', 'bonds'],
            'digital_banking': ['online', 'mobile', 'internet', 'app', 'password', 'login'],
            'customer_service': ['help', 'support', 'complaint', 'issue', 'problem', 'assist']
        }

        # Common question and action patterns
        self.patterns = {
            'question_starters': ['how', 'what', 'where', 'when', 'can', 'do'],
            'action_verbs': ['want', 'need', 'get', 'apply', 'check', 'view', 'make', 'send'],
            'intent_indicators': ['i want to', 'i need to', 'how do i', 'how can i', 'where do i']
        }

    def load_content(self) -> List[str]:
        """Load all content from scraped files"""
        content = []
        for filename in os.listdir(self.content_dir):
            if filename.endswith(('.txt', '.md', '.html')):
                with open(os.path.join(self.content_dir, filename), 'r', encoding='utf-8') as f:
                    content.append(f.read())
        return content

    def extract_sentences(self, text: str) -> List[str]:
        """Extract and clean sentences from text"""
        doc = self.nlp(text)
        sentences = []
        for sent in doc.sents:
            # Clean and normalize sentence
            clean_sent = re.sub(r'\s+', ' ', sent.text).strip()
            clean_sent = re.sub(r'[^\w\s\-.,?!()]', '', clean_sent)
            if clean_sent:
                sentences.append(clean_sent.lower())
        return sentences

    def categorize_sentence(self, sentence: str) -> str:
        """Determine the banking category of a sentence"""
        sentence = sentence.lower()
        max_matches = 0
        best_category = 'general'

        for category, keywords in self.banking_categories.items():
            matches = sum(1 for keyword in keywords if keyword in sentence)
            if matches > max_matches:
                max_matches = matches
                best_category = category

        return best_category

    def generate_intent_variations(self, sentence: str) -> List[str]:
        """Generate different variations of an intent"""
        variations = set()
        doc = self.nlp(sentence)

        # Original sentence
        variations.add(sentence)

        # Generate question form
        for starter in self.patterns['question_starters']:
            if not sentence.startswith(starter):
                variations.add(f"{starter} {sentence}")

        # Generate action form
        for verb in self.patterns['action_verbs']:
            if not sentence.startswith(f"i {verb}"):
                variations.add(f"i {verb} to {sentence}")

        # Remove duplicate words and clean up
        clean_variations = set()
        for var in variations:
            clean_var = ' '.join(dict.fromkeys(var.split()))
            clean_var = re.sub(r'\s+', ' ', clean_var).strip()
            if len(clean_var.split()) > 2:  # Only keep phrases with 3+ words
                clean_variations.add(clean_var)

        return list(clean_variations)

    def cluster_similar_intents(self, intents: List[str], n_clusters: int = 5) -> List[str]:
        """Cluster similar intents and select representatives"""
        if len(intents) <= n_clusters:
            return intents

        # Create TF-IDF matrix
        vectorizer = TfidfVectorizer()
        tfidf_matrix = vectorizer.fit_transform(intents)

        # Perform clustering
        kmeans = KMeans(n_clusters=n_clusters, random_state=42)
        clusters = kmeans.fit_predict(tfidf_matrix)

        # Select representative intents from each cluster
        representatives = []
        for i in range(n_clusters):
            cluster_intents = [intent for j, intent in enumerate(intents) if clusters[j] == i]
            if cluster_intents:
                # Select the shortest intent as representative
                representative = min(cluster_intents, key=len)
                representatives.append(representative)

        return representatives

    def generate_intents(self) -> Dict[str, List[str]]:
        """Generate comprehensive intents from content"""
        # Load and process content
        content = self.load_content()
        all_sentences = []
        for text in content:
            all_sentences.extend(self.extract_sentences(text))

        # Organize sentences by category
        categorized_sentences = defaultdict(list)
        for sentence in all_sentences:
            category = self.categorize_sentence(sentence)
            categorized_sentences[category].append(sentence)

        # Generate final intents
        final_intents = {}
        for category, sentences in categorized_sentences.items():
            # Generate variations for each sentence
            all_variations = []
            for sentence in sentences:
                variations = self.generate_intent_variations(sentence)
                all_variations.extend(variations)

            # Remove duplicates
            unique_variations = list(set(all_variations))

            # Cluster similar intents to reduce redundancy
            if len(unique_variations) > 20:
                final_intents[category] = self.cluster_similar_intents(
                    unique_variations,
                    n_clusters=min(20, len(unique_variations))
                )
            else:
                final_intents[category] = unique_variations

        return final_intents

def main():
    # Initialize generator
    generator = IntentGenerator('/content/bank_content')

    # Generate intents
    intents = generator.generate_intents()

    # Print results
    for category, intent_list in intents.items():
        print(f"\n{category.upper()} ({len(intent_list)} intents):")
        for intent in intent_list:
            print(f"- {intent}")
        print("-" * 50)

if __name__ == "__main__":
    main()
# Out:
# DIGITAL_BANKING (20 intents):
# - career gtbank uganda source httpswww.gtbank.co.ugcareer online banking .
# - corporate governance gtbank uganda source httpswww.gtbank.co.ugaboutour-companycorporate-governance online banking our company brand affiliations personal business about us help security quick links history people recognition and awards financial information pillar 3 market discipline disclosures guaranty trust bank (uganda) limited is committed to adhering the highest standards of good at all levels its operations.
# - help centre gtbank uganda source httpswww.gtbank.co.ughelp-centre online banking topics personal business about us security quick links 2025 guaranty trust bank, uganda.
# - these rules signify our collective belief and guide approach to work.
# - internship graduates application process navigate learn more personal banking business about us help security quick links
# - it is an internet-based solution that enables online payments using local as well international cards such mastercard.
# - apply and finance your vehicles, capital equipment machinery with ease.
# - videos gtbank uganda source httpswww.gtbank.co.ugmedia-centrevideos online banking media centre browse personal business about us help security quick links all content in the news press releases there are no items for this section.
# - this mobile banking platform has an option of the customer using gtworld app or a ussd code 237 to access gtbank services.
# - - processing your job application if you apply for a with us, including sensitive data medical screening.
# - cookies are small text files stored on your computer or mobile devices whenever you visit a website.
# - gtbanks websites, products, applications, and services may contain links to third-party products services.
# - log on or register for internet banking in just a few minutes.
# - services gtbank uganda source httpswww.gtbank.co.ugbusiness-bankingservices online banking business smart solutions for successful businesses.
# - how corporate executive t e card gtbank uganda source httpswww.gtbank.co.ugbusiness-bankingcardscorporate-executive-t-e-card online banking about this features benefits to apply navigate personal business us help security quick links the te provides a tailored solution for companies whose staffs or managements have substantial travel entertainment expenses.
# - can registrations be done at our branches and online.
# - you must notify us immediately if your physicalresidential, postal, email address or mobile number, change.
# - we take appropriate technical and organizational measures to prevent loss, unauthorized access, misuse, modification or disclosure of information under our control.
# - this is applicable to both domestic and international trade.
# - our people gtbank uganda source httpswww.gtbank.co.ugaboutour-companypeople online banking company
# --------------------------------------------------
#
# CUSTOMER_SERVICE (20 intents):
# - gg navigate personal banking business about us help security quick links .
# - - good communication, marketing and negotiation skills leadership management excellent problem solving, analytical, attention to detail, decision-making, team leading skills.
# - throughout our history, we have continued to help staff realize their dreams, whilst creating opportunities for them fulfill personal and professional potential.
# - any notices so issued by us, will as far they contain contractual terms relating to electronic banking, also form part of this agreement 5.4 unless clearly stated, information on our communication media is intended provide you with only general about the bank, its products, services and objectives.
# - in this regard, guaranty trust bank (uganda) limited continues to design and provide efficient solutions digitally towards offering collection services on behalf of ura support their revenue initiatives.
# - in compliance with set out regulatory guidelines. - monitor and take action to improve digital financial services banking operational efficiency effectiveness, support functions resolve issues, reviewing procedures, automating processes efficiency.
# - - team player inter-personal and customer service skills excellent leadership administrative ability to work under pressure direct manage all teams of technology group the staff department, planning organizing their activities, setting targets, monitoring performance giving support, instruction advice design implement strategic information plans budgets for cost-effective procurement, utilization maintenance computer software hardware formulate, monitor it disaster recovery security policies procedures. management vendors negotiate level agreements suppliers ensure are met, leases contracts compliance with terms proper licensing components is done.
# - - complying with our legal obligations and assisting government law enforcement agencies or regulatorssupervisors identifying informing you about other products services that we think may be of interest to you.
# - the product is perfect for undergraduates and students in tertiary institutions to help them learn a saving culture while as making use of digital banking channels perform transactions.
# - we only retain information that allows us comply with legal and regulatory requests for certain data, meet business audit requirements, respond to complaints queries, or address disputes claims may arise. data which is not retained securely destroyed when it identified no longer needed the purposes was collected.
# - the service helps importers who wish to match cash outflows with receivables.
# - - build capacity, manage and coach team members. prepare submit management regulatory reports on all aspects of digital financial supervision support.
# - well help you choose the one that will get there.
# - - a minimum of 7 years experience in information technology with at least 5 middle management. ccna, mcse, mcsa and cla are added advantages thorough knowledge database management systems technologies especially sybase, microsoft sql server or oracle writing scripts using transact-sql software development methodologies languages .net java managing multiple rdbms on large strong project management, problem solving, reporting analytical skills ability to think strategically good communication, interpersonal, leadership strategic planning responsible for the implementation bank service strategy branch level. coordinate activities front back office ensure effective both internal external clients. manage risks controls affecting that necessary steps taken measure, monitor control these risks.
# - cookies have many uses, such as memorizing your preferences to tailor experiences while on our site or help us analyse website traffic.
# - innovative banking products our initiatives gtbank share prices personal business about us help security quick links three times consecutive winner of the ura digital innovation award.
# - complaints enquiries gtbank uganda source httpswww.gtbank.co.ughelp-centrecomplaints-enquiries online banking personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - whatever your business or its size, we have what it takes to help you grow.
# - people, our centre navigate learn more personal banking business about us help security quick links at guaranty trust bank, we understand that building a world-class institution is only possible when have the right people.
# - fun. employee value proposition work environment life outside navigate learn more personal banking business about us help security quick links
# --------------------------------------------------
#
# GENERAL (20 intents):
# - - orange relates to a person who has great practical-hands on-skills.
# - - easy access to bank information and products.
# - corporate social responsibility gtbank uganda source
# - - if an offer is not made to you in person.
# - - request that your information be erased.
# - i view to 1.
# - i send to 6.
# - 2025 guaranty trust bank, uganda.
# - - a minimum of 3 years experience in digital banking.
# - i want to 5.
# - put the cash in your business to work.
# - you shall not change any of these terms.
# - why join gtbank?
# - i get to 12.
# - do memorize it.
# - we are a team driven to deliver the utmost in customer service.
# - i need to 1.
# - i get to 3.
# - i need to 10.
# - working with us our vision mission culture
# --------------------------------------------------
#
# CARDS (20 intents):
# - mastercard platinum debit card this is a uganda shilling denominated for high net worth individuals corporates.
# - when in addition to this agreement, the terms and conditions of your debit card pre-paid accounts(s) or facility shall apply all transactions you carry out instruct bank through accounts linked account number select using electronic banking.
# - atm mobile banking 237 internet cards 2025 guaranty trust bank, uganda.
# - gtbank has deployed a large network of atms to offer our customers easy access their funds 24 hours every day.
# - how about this card features benefits to apply 2025 guaranty trust bank, uganda.
# - these are physical cards that enables a customer perform transactions using atm machines, point sale machines and online payments.
# - a platinum card holder will have access to mastercard global services (24hour through which you can receive emergency assistance by telephone) dollar debit
# - - request to block card.
# - accountways to bankways bank overviewatmscardsloansloansloans overviewsalary loanspersonal development loansservicesservicesservices
# - do not keep any written copy of your pin with card.
# - you can quickly and conveniently carry out 100 of your banking transactions with debit card.
# - the platform accepts both visa card and mastercard, issued anywhere in world.
# - can the guaranty trust bank uganda website contains or may contain information, communications, opinions, text, graphics, links, electronic art, animations, audio, video, software, photos, music, sounds and other material data (collectively, content) formatted, organized collected in a variety of forms that are generally accessible to users, including directories databases, areas be modified by such as posting classifieds, uploading multimedia files, registering user profiles, creating auto-notify, personalized pages, project areas.
# - please note that any content you post to such social media platforms (e.g. pictures, information or opinions), as well personal otherwise make available users your profile) is subject the applicable terms of use and privacy policies.
# - upon the selection of payment option, payee or person paying would be required to input his card details (card number, expiry date, pin etc) for processing.
# - once the payment process is completed, payees account debited instantly and university credited.
# - 3.4 you must report any compromise of your access codepin to us without delay through our customer service or branch.
# - sks teen holders qualify to be issued atm cards upon parentswards request.
# - the e-zwich smartcard is a new and very secure way of handling cash based on biometric (finger print) identification.
# - cookies can be used for a variety of purposes such as identifying users, keeping track preferences and activity (e.g. language, currency, ip address time zone).
# --------------------------------------------------
#
# LOANS (20 intents):
# - jobs gtbank uganda source httpswww.gtbank.co.ugaboutcareer online banking learn more personal business about us help security quick links position head, credit administration reporting to managing director purpose of the director, job holder is directly responsible for policies, processes quality bank portfolio compliance thereof with internal regulatory requirements.
# - invoice discounting gtbank uganda source httpswww.gtbank.co.ugbusiness-bankingloansinvoice-discounting online banking personal business about us help security quick links
# - salary loans personal development select up to 3 products compare 2025 guaranty trust bank, uganda.
# - we also arrange for confirmation of letters credit by a range world-class international banking institutions.
# - the extension of such a line credit is normally covered by provision acceptable tangible collateral.
# - choose from our wide range of simple and straightforward loan offers for your personal needs the projects you care about.
# - - establishing your identity and assessing applications for our products services pricing designing administering managing relationship with you risks identifying investigating illegal activity (i.e.), such as fraud contacting you, example in instances where we suspect on account or when the need arises to tell about recent occurrences banking sector some event(s) of significance. conducting improving businesses experience us reviewing credit loan eligibility.
# - - preventing money laundering or terrorism financing activities.
# - term loans gtbank uganda source httpswww.gtbank.co.ugbusiness-bankingloansterm-loans online banking personal business about us help security quick links
# - a bankers acceptance is low cost loan over the normal cash conversion cycle for specific shipment or lot of inventory.
# - the business of bank is driven by board directors which exercises its oversight function through various committees, namely risk management committee, credit human resources and compensation committee audit committee.
# - this growth trajectory in the partnership only signifies that our future is orange and will leverage competitive abilities to remain relevant even as we transition a tier 2 credit finance institution.
# - we may also disclose information about you if determine that for purposes of national security, law enforcement, or other issues public importance, disclosure is necessary appropriate. - external auditors gtbanks staff credit agencies correspondent banks strategic partnersservice providers the purpose improving and providing our products services to you.
# - our bill financing service covers both letter of credit-backed discounting and clean discounting.
# - as a bank with international reach, we have come to identify loan syndications part of our core business, and by pursing this line aggressively are at point where be recognized major player in field.
# - if you are considering a large acquisition or major project, may need significant amount of credit.
# - this undertaking is similar to that of a letter credit and hence provides the same comfort supplier but with an easier structure for importer.
# - the money market refers to borrowing and lending for periods of a year or less.
# - - a minimum of 7 years experience in credit management with at least 5 middle management.
# - do you need financing for up to 180 days?
# --------------------------------------------------
#
# ACCOUNT (20 intents):
# - gtseniors account - gtcrea8 gtsacco gtbusiness accounts gtbank ngo gtmax (for both individual business) gtschool standard gtesteem gtpersonal our company careers why join gtbank? working at recognition and awards press release-tier 2 reactivation complaints enquiries newsletter subscription security centre whistle blower deposit protection fund find a branchatm download forms media open an contact address list of dormant 256 200 710 500 703 718 785 866 559 website tc digital services privacy policy sitemap deposits are protected by upto 10m
# - save tomorrow today, with our high interest and low charges savings investment accounts.
# - 2.8 we may check and confirm any record of a deposit into your account.
# - accountgtpersonal account - accounts overview gtbusiness gtmax (for both individual business) gtbank ngo standard gtesteem gtschool gtpersonal loansloansloans overviewterm loansbill discountinginvoice discountinggt trade financegt finance overviewletter of creditimport letters credit servicesexport servicesdocumentary collectionsdocumentary import collectionsexport documentary collectionsclean collectionsnegotiation export billsbill avalisation servicesuppliers financingpost-import financingbank guarantees loans term bill discounting invoice gt letter services collections clean negotiation bills service suppliers financing post-import bank servicesservicesservices overviewdigital channelsdigital channels overviewgtworldinternet bankinggtschool collectgtmaster cardsmyugpaygtpaymerchant collectiongtremitguaranty trust automated payment system (gaps) digital gtworld internet banking collect gtmaster cards myugpay gtpaymerchant collection gtremit guaranty about us our companyour company overviewour historyour peoplepeople and culturerecognition awardsbrand history people culture recognition awards brand careerscareerscareers overviewwhy join gtbank?working at gtbankcareer opportunitiesavailable jobsscam job offers careers why gtbank? working career opportunities available jobs scam corporate social responsibilitycorporate responsibility approach investor relations financial information pillar 3 market discipline disclosures open an pay tax select location ugandaugandacote divoiregambiaghanakenyaliberianigeriarwandasierra leonetanzaniaunited kingdom uganda cote divoire gambia ghana kenya liberia nigeria rwanda sierra leone tanzania united locate a branch or atm branchlocate help centre media security personal business zero opening minimum balance monthly fee interest rate per annum
# - do digital account
# - open account gtbank uganda source httpswww.gtbank.co.ugaboutopen-account online banking learn more personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - - online real-time account monitoring facility.
# - business accounts loans whether you are just starting up or looking to grow your
# - an additional professional and or academic qualification in banking, accounting finance will be added advantage.
# - in the event of conflict between provisions this agreement and bank cardaccountproduct terms or any other term, shall prevail.
# - - check your balance, monitor transactions and print account statement.
# - (b) you may not modify, copy, reproduce, transmit, distribute, publish, create derivative works from, display or otherwise transfer commercially exploit any of the content, in whole part, provided, however, that (i) make a reasonable number digital other form copies to permit your computer hardware and software access view (ii) print one copy each piece (iii) distribute hard electronic for internal use only.
# - accounts gtbank uganda source httpswww.gtbank.co.ugpersonal-bankingaccounts online banking personal turn your goals into reality.
# - the corporate governance rubrics of bank are designed to ensure accountability board and management stakeholders.
# - terms of operating a gtdigital account nb all other services transaction charge are applicable as per the tariff guide 11.0 general 11.1
# - we do not knowingly market to children nor allow under 18 open online accounts.
# - our business accounts help you focus on making your a success.
# - maintaining accurate information keeping your account and up to date is very important.
# - we will allow you an opportunity to begin using your account again, after which, if have not begun it close it.
# - subscribe to sms alerts be delivered your cell phone or email, so you can stay updated on account activity.
# --------------------------------------------------
#
# PAYMENTS (20 intents):
# - under no circumstance does gtbank request fees from job applicants.
# - accountgtpersonal account - accounts overview gtbusiness gtmax (for both individual business) gtbank ngo standard gtesteem gtschool gtpersonal loansloansloans overviewterm loansbill discountinginvoice discountinggt trade financegt finance overviewletter of creditimport letters credit servicesexport servicesdocumentary collectionsdocumentary import collectionsexport documentary collectionsclean collectionsnegotiation export billsbill avalisation servicesuppliers financingpost-import financingbank guarantees loans term bill discounting invoice gt letter services collections clean negotiation bills service suppliers financing post-import bank servicesservicesservices overviewdigital channelsdigital channels overviewgtworldinternet bankinggtschool collectgtmaster cardsmyugpaygtpaymerchant collectiongtremitguaranty trust automated payment system (gaps) digital gtworld internet banking collect gtmaster cards myugpay gtpaymerchant collection gtremit guaranty about us our companyour company overviewour historyour peoplepeople and culturerecognition awardsbrand history people culture recognition awards brand careerscareerscareers overviewwhy join gtbank?working at gtbankcareer opportunitiesavailable jobsscam job offers careers why gtbank? working career opportunities available jobs scam corporate social responsibilitycorporate responsibility approach investor relations financial information pillar 3 market discipline disclosures open an pay tax login home personalpersonalpersonal overviewaccountsaccountsaccounts overviewgtsavegtsave plussmart kids save accountgttargetgtseniors accountgtsacco
# - pay tax gtbank uganda source httpswww.gtbank.co.ugpay-tax online banking personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - it includes any payment for goods or services cash in out transfer of money value.
# - can gtpay allows integrations on several other platforms and be customized to fit the customers need.
# - gtpay is available for any merchants with or without website.
# - details of our subscription and transaction fees are available on website branches 1.2.
# - - if you are being asked to pay any fees or enter into financial agreement.
# - we understand that being an employer of choice goes beyond the regular pay package.
# - if you fail to pay our fees or have insufficient funds in the account which selected for this purpose, we reserve right refuse access relevant electronic banking service and debit all outstanding any other with bank 2.
# - such transactions include wallet to bank transfer, bill payment, buy airtime etc.
# - it can be used for atm cash withdrawals and also to settle purchasespayments via pos terminals.
# - the service also enables parentsstudents to pay fees conveniently using phones.
# - the two most common conditions for release are documents against payment (dp) released only if importer makes immediate payment.
# - fees and other charges 1.1.
# - this platform is designed to enable schools receive, manage and monitor fees payments in real-time.
# - bill discounting gtbank uganda source httpswww.gtbank.co.ugbusiness-bankingloansbill-discounting online banking personal business about us help security quick links
# - you must pay all our expenses for recovering any amounts owe us, including legal fees of an attorney, collection and tracing fees.
# - the importer may be able to negotiate a lower purchase price and transactions can re-structured as trade payables instead of short-term bank debt.
# - the process for payments is simple and straight forward.
# --------------------------------------------------
#
# INVESTMENTS (20 intents):
# - do if notified of content that is alleged not to conform this agreement, guaranty trust bank uganda may investigate the allegation and determine in its sole discretion whether remove or request user such content.
# - i send to they offer a broad range of services, which includes advisory and funds management for high net worth individuals, corporate organizations institutional investors with emphasis on client specific requirement in relation yield, safety administration.
# - i get to investor relations gtbank uganda source httpswww.gtbank.co.uginvestor-relations online banking browse share prices personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - what under this service, funds can be invested in short or long term money securities like commercial papers (cps), bankers acceptances (bas), tenored deposits, treasury bills (t-bills) and government bonds.
# - it does not constitute an offer or solicitation to buy sell, dispose in any way, of investment enter into transaction 5.5 you must check each statement as soon get (frequency delivery will be agreed by both parties) and notify the bank within 60 days date if think that is correct.
# - how our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - if notified of content that is alleged not to conform this agreement, guaranty trust bank uganda may investigate the allegation and determine in its sole discretion whether remove or request user such content.
# - i check to our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - where our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - i check to under this service, funds can be invested in short or long term money securities like commercial papers (cps), bankers acceptances (bas), tenored deposits, treasury bills (t-bills) and government bonds.
# - investor relations gtbank uganda source httpswww.gtbank.co.uginvestor-relations online banking browse share prices personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - i apply to our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - under this service, funds can be invested in short or long term money securities like commercial papers (cps), bankers acceptances (bas), tenored deposits, treasury bills (t-bills) and government bonds.
# - i want to if notified of content that is alleged not conform this agreement, guaranty trust bank uganda may investigate the allegation and determine in its sole discretion whether remove or request user such content.
# - they offer a broad range of services, which includes advisory and funds management for high net worth individuals, corporate organizations institutional investors with emphasis on client specific requirement in relation to yield, safety administration.
# - our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - i view to our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - how investor relations gtbank uganda source httpswww.gtbank.co.uginvestor-relations online banking browse share prices personal business about us help security quick links 2025 guaranty trust bank, uganda.
# - i need to our team of specialist on funds management desk is responsible for investing your in high yielding money market securities.
# - when investor relations gtbank uganda source httpswww.gtbank.co.uginvestor-relations online banking browse share prices personal business about us help security quick links 2025 guaranty trust bank, uganda.
# --------------------------------------------------
#
# TRANSFERS (20 intents):
# - if we fail to confirm receipt of your instruction, do not re-send the same instruction before checking statements or contacting our customer service.
# - whenever your information is transferred to other locations, we will take all necessary steps ensure that data handled securely and in accordance with this privacy policy.
# - your right of access can be exercised by sending an email to enquiriesuggtbank.com -
# - gtremit gtbank uganda source httpswww.gtbank.co.ugpersonal-bankingservicesservices-2-2services-2-3-2-2-2 online banking compare products personal business about us help security quick links is used by accounts holders to send money non-customers through our branches.
# - telephone 256 200 710 500 703 718 785 866 559e-mail enquiriesuggtbank.com swift code gtbiugka sort 650147 2025 guaranty trust bank, uganda.
# - upon submission of the information, customers will then receive notification from bank on status their transaction via emails without having to visit bank.
# - - funds transfer to other banks. mobile phone airtime top-up.
# - we may at any time change these terms by sending you notice.
# - this service helps exporters who wish to receive immediate value for goods shipped under a letter of credit or collection.
# - key responsibilities desired knowledge, skills and abilities set all interested candidates should send their application including cover letter, cv academic documents to the head of human resources, guaranty trust bank uganda by hand delivery or email jobsuggtbank.com 05th january 2025.
# - 5.3 permit us to issue notices required in terms of this agreement, legislation or regulation by mail sending such notifications post, email, fax similar future technologies.
# - - send money form gtbank account to mtn airtel mobile wallets ie wallet transfers. receive from mtnairtel directly onto pin change.
# - where once the documentation is received by gtbank, it forwarded to importers bank, from funds will be collected at a later date.
# - inward transfers funds are received from abroad through our correspondent banks for further credit into customers foreign currency accounts with us in ghana.
# - we may also use information received from third parties such as family, solicitors, friends, or employers, website social media pages made public by you, government agencies, regulators, supervisory credit agencies.
# - gtbank receives import documents with a draft drawn on the importer.
# - when identity verification will be followed to prevent someone else from impersonating you 3.5 notify us disable your access code, we are entitled 3.5.1 reject all instructions received after such notifications 3.5.2 suspend the processing of not yet executed 3.5.3 reverse (if possible) transactions with effect date and time as may reasonable determine unauthorized use have 3.5.4 deactivate codepin without further notice 3.6 do disclose an code any person including a member our staff or customer service 4.
# - additionally, in the event of a reorganization, merger, or sale we may transfer any and all personal information collect to relevant third party.
# - send your details to jobsuggtbank.com guaranty trust bank is committed constantly grooming young talents and providing them with opportunities explore their strengths, discover themselves, make an impact in the environment.
# - benefits to customers prompt and secure way of transferring funds from ghana about this service 2025 guaranty trust bank, uganda.
# --------------------------------------------------

# %%
def main():
    # Initialize classifier
    classifier = IntentClassifier(intents)

    # Example messages
    test_messages = [
        "I want to open a new account",
        "My Yaka payment failed but money was deducted",
        "How do I receive money from USA?",
        "Need to pay my electricity bill",
        "i need a card",
        "is there hospital payments"
    ]

    # Test classification
    for message in test_messages:
        result = classifier.ensemble_classify(message)
        print(f"Message: {message}")
        print(f"Classified Intent: {result}\n")

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: I want to open a new account
# Classified Intent: open_account
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: My Yaka payment failed but money was deducted
# Classified Intent: bill_payment
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: How do I receive money from USA?
# Classified Intent: transfer_money
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: Need to pay my electricity bill
# Classified Intent: bill_payment
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: i need a card
# Classified Intent: menu
# <ipython-input-31-d03805ce3050>:67: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   similarity = doc.similarity(example_doc)
# Message: is there hospital payments
# Classified Intent: general
